# %%
import json, sys, re, time, dns
import pymongo, sys
from pymongo import MongoClient
from datetime import datetime, timedelta

# %%
#==============================================================================
# 02-aggregagate-user-data.py
# Purpose: takes tweets collections and aggregates user data (e.g. followers;
# number of tweets in each collection, etc), necessary to prepare list of 
# users that will be included in the analysis. Note that here we're already
# applying the spam and activity filters.
# Author: Pablo Barbera
#==============================================================================


## Export user data from a collection, aggregated at the user
## level (note that for users with more than one tweets, only
## their most recent user data is kept)
## Data will be stored in separate files for each collection,
## with the format "temp/user_list_COLLECTION_NAME"

def export_userlist(collection_name):
    data = sp.find({'followers_count':{'$gte':25},
        'statuses_count':{'$gte':100},
        'friends_count':{'$gte':100} },
        ['user_id_str','id_str', 'followers_count', 'lang', 'location'])
    print("Counting tweets...") 
    tw = data.count()   
    i = 0
    user_list = {}
    user_data = {}
    print("Extracting data...")
    for t in data:
        i += 1
        if i % 1000 == 0:
            print(str(i) + '/' + str(tw))
        try:
            user_id = t['user_id_str']
            tweet_id = t['id_str']
#            print("user id is : ", user_id)
        except:
            continue
        user_list[user_id] = 1 + user_list.get(user_id,0)
        user_data[user_id] = "{0},{1},{2},{3},{4},{5}".format(
            t['user_id_str'],
            t['id_str'],
            t['followers_count'],
            t['lang'],
            t['location'].replace(",", "").replace("\n","").encode("utf-8"),
            user_list[user_id]) 
        

    outhandle = open('/Users/alex/Documents/GitHub/PLSC508_rep/dowloaded/user_list/user_list_' + collection_name +'.csv', "w")
    file_key = "user_id_str,id_str,followers_count,lang,location,tweets"
    outhandle.write("{0}\n".format(file_key))
    for user, user_string in user_data.items():
        outhandle.write("{0}\n".format(user_string))
### Now we apply the function to all our collections

# %%
uri = "mongodb+srv://zvb5133:Bi19970130!@plsc508.1ejljrz.mongodb.net/?retryWrites=true&w=majority"
cluster = pymongo.MongoClient(uri)

# %%
import pprint
import tweepy
pprint.pprint(sp.find_one())
temp = sp.find_one(3)
# Out:
# {'_id': ObjectId('63516fef2d6a9a52fb0bb482'),
#  'created_at': 'Mon Feb 03 19:12:53 +0000 2014',
#  'description': "I'm a Seeker. Acting my own life, Directing my own path. What "
#                 'to think. What to feel. How to act, how to speak, insecure, '
#                 'Incomplete! LEARNING MODE!',
#  'favorite_count': 9.0,
#  'favorited': False,
#  'favourites_count': 19327.0,
#  'followers_count': 2759.0,
#  'friends_count': 2351.0,
#  'geo_enabled': True,
#  'id_str': '430418634628816896',
#  'lang': 'en',
#  'listed_count': 63.0,
#  'location': 'CA',
#  'name': 'waly mury',
#  'protected': False,
#  'retweet_count': 15.0,
#  'retweeted': False,
#  'screen_name': 'walymury',
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'statuses_count': 45138.0,
#  'text': 'RT @WHLive: Obama to a man from WI making the minimum wage: “We’ve '
#          'got to make sure work pays.” #RaiseTheWage, http://t.co/aVSJ5vBdxQ',
#  'truncated': False,
# ...

# %%
temp['id_str']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 temp['id_str']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
consumer_key = '3vQSi5O49WuSXwtrPpCF2gzRc'
consumer_secret = 'XwyX95s16KGtPgSHryamnjQJpiokzT4AtQB35j8JDRK7IQFQmN'
access_token = '1314960594043310080-p8kauSNNsmrqC21eXU2aBnM5OFvw6A'
access_token_secret = 'cRdNjjnfYADGlVrd6ktLAO7Lv9DswByYFhCDgcEVr2pBX'

# %%
from twitter import *
user = "ideoforms"
#-----------------------------------------------------------------------
# load our API credentials 
#-----------------------------------------------------------------------
import sys
sys.path.append(".")
#-----------------------------------------------------------------------
# create twitter API object
#-----------------------------------------------------------------------
twitter = Twitter(auth = OAuth(access_token,
                  access_token_secret,
                  consumer_key,
                  consumer_secret))

# %%
#-----------------------------------------------------------------------
# perform a basic search 
# twitter API docs: https://dev.twitter.com/rest/reference/get/statuses/user_timeline
#-----------------------------------------------------------------------
user = "ideoforms"
results_1 = twitter.statuses.user_timeline(screen_name = user)


#-----------------------------------------------------------------------
# loop through each of my statuses, and print its content
#-----------------------------------------------------------------------
for status in results_1:
    print("@%s %s" % (user, status["text"]))

    #-----------------------------------------------------------------------
    # do a new query: who has RT'd this tweet?
    #-----------------------------------------------------------------------
    retweets_1 = twitter.statuses.retweets._id(_id = status["id"])
    for retweet in retweets_1:
        print(" - retweeted by %s" % (retweet["user"]["screen_name"]))
# Out:
# @ideoforms @grahamdunning ahh, the buzz of browsing the Experimental / Avant / Post Rock sections in that place circa the early 00s - can't beat it.
# @ideoforms congrats to @RogueAmoeba for 20 years of making excellent + essential audio tools for macOS. 🙏 all their stuff is c… https://t.co/kG3HHM2Wdo
# @ideoforms beyond excited to discover that a new monkey island game has been created by the original team of writers and compo… https://t.co/BHZyGwBptF
#  - retweeted by davidchatting
# @ideoforms RT @jones_bulley: Maelstrom (2022) opens this week at Science Gallery Melbourne @scigallerymel as part of SWARM, a multidisciplinary exhibi…
# @ideoforms @fedbybirds 😧 I hope not!
# @ideoforms @teropa this truly is the interview that keeps on giving. thanks for all the work on this digest!
# @ideoforms this is shaping up to be a vintage edition of Late Junction: @do_or_diy, @jemfiner, and “tropical chamber jazz […]… https://t.co/EZA11Ncx5h
# ...

# %%
retweets_1
# Out:
# []

# %%
connection = cluster

# collections = ["BostonBombing", "GunControl", "MinimumWage",
# 	"USElection", "superbowl", "MarriageEquality", "Budget", "Syria",
# 	"GovernmentShutdown", "oscars", "SOTU",	"olympics"]

collections = ["PLSC508"]

for col in collections:
	db = connection[col]
	sp = db.Barbera2015
	export_userlist(col)
# Out:
# Counting tweets...
# /var/folders/0_/bsq6qcp57hj5r09d3t06gzmm0000gn/T/ipykernel_73254/1114508264.py:23: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   tw = data.count()
# Extracting data...
# 1000/152996
# 2000/152996
# 3000/152996
# 4000/152996
# 5000/152996
# 6000/152996
# 7000/152996
# 8000/152996
# 9000/152996
# 10000/152996
# 11000/152996
# 12000/152996
# 13000/152996
# 14000/152996
# 15000/152996
# 16000/152996
# 17000/152996
# 18000/152996
# 19000/152996
# 20000/152996
# 21000/152996
# 22000/152996
# 23000/152996
# 24000/152996
# 25000/152996
# 26000/152996
# 27000/152996
# 28000/152996
# 29000/152996
# 30000/152996
# 31000/152996
# 32000/152996
# 33000/152996
# 34000/152996
# 35000/152996
# 36000/152996
# 37000/152996
# 38000/152996
# 39000/152996
# 40000/152996
# 41000/152996
# 42000/152996
# 43000/152996
# 44000/152996
# 45000/152996
# 46000/152996
# 47000/152996
# 48000/152996
# 49000/152996
# 50000/152996
# 51000/152996
# ...

# %%
	db = connection[col]
	sp = db.Barbera2015
	# query only those tweets coming from users who passed our filter
	data = sp.find({'followers_count':{'$gte':25},
		'statuses_count':{'$gte':100},
		'friends_count':{'$gte':100},
		 'retweeted':True })

# %%
data.count()
# Out:
# /var/folders/0_/bsq6qcp57hj5r09d3t06gzmm0000gn/T/ipykernel_73254/3975387472.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   data.count()
# 0

# %%
### The final step is to aggregate all the user-level datasets into
### a single dataset

users = {}
tweets = {}

for col in collections:
	print (col)
	tweets[col] = {}
	d = open('/Users/alex/Documents/GitHub/PLSC508_rep/dowloaded/user_list/user_list_' + col + '.csv', 'r')
	d.readline()
	for line in d:
		try:
			w = line.rstrip().split(",")
		except:
			continue
		try:
			if w[3] == 'en':
				users[w[0]] = ",".join(w[1:5])
				tweets[col][w[0]] = w[5]
		except:
			continue
# Out:
# PLSC508

# %%
users
# Out:
# {'353063439': "449247904759169024,2760.0,en,b'CA'",
#  '16910252': "455469351479820289,17734.0,en,b'Washington DC'",
#  '96894306': "453517206383771648,11378.0,en,b'Outside as much as possible'",
#  '24261049': "453992902126215169,2120.0,en,b'Maryland'",
#  '451043636': "430420807915798529,757.0,en,b'Chicago'",
#  '501276670': "430420357716385792,182.0,en,b'Pittsburgh PA'",
#  '1543535868': "434491211236528129,720.0,en,b'Wonderland '",
#  '15278752': "453330641078059008,2218.0,en,b'Ohio USA'",
#  '341564179': "430416640854220800,561.0,en,b'Philadelphia'",
#  '544564185': "451445722949230592,820.0,en,b'Colorado USA'",
#  '162708536': "430431200809717760,555.0,en,b'Portland OR'",
#  '109071031': "453253267431391232,263663.0,en,b'Maryland USA'",
#  '1697688301': "430431529479585792,298.0,en,b'Arlington VA'",
#  '1062993338': "430578840872964096,43.0,en,b'Modena'",
#  '286322844': "455450944785092608,2768.0,en,b'Cherry Hill NJ'",
# ...

# %%
tweets
# Out:
# {'PLSC508': {'353063439': '17',
#   '16910252': '128',
#   '96894306': '22',
#   '24261049': '43',
#   '451043636': '2',
#   '501276670': '2',
#   '1543535868': '3',
#   '15278752': '126',
#   '341564179': '2',
#   '544564185': '3',
#   '162708536': '6',
#   '109071031': '5',
#   '1697688301': '2',
#   '1062993338': '3',
#   '286322844': '17',
#   '91734908': '2228',
#   '334296203': '4',
#   '30741989': '66',
#   '1458247532': '12',
#   '2206963340': '30',
#   '856732580': '3',
#   '1150002710': '10',
#   '113543869': '11',
#   '22926853': '7',
#   '1135362566': '79',
#   '550097439': '2',
#   '497239737': '5',
#   '76355393': '4',
#   '72010438': '2',
#   '594863522': '1077',
#   '2196759704': '2',
#   '112537940': '2',
#   '77943803': '2',
#   '904587835': '5',
#   '78778106': '4',
#   '15249499': '10',
#   '387162020': '7',
#   '1102161270': '283',
#   '14370819': '2',
#   '62364413': '2',
#   '1595668502': '3',
#   '543675296': '2',
#   '26031465': '4',
#   '44618911': '5',
# ...

# %%
lists = ['PLSC508']


outhandle = open('/Users/alex/Documents/GitHub/PLSC508_rep/dowloaded/user_list/user_list_full.csv', 'w')
ulist = users.keys()
file_key = 'user_id_str, id_str,followers_count,lang,location,' + ",".join(lists)
outhandle.write(file_key + "\n")
for u in ulist:
	tw = []
	for l in lists:
		tw.append(tweets[l].get(u, '0'))
	if tw.count('0') == 11:
		continue
	lw = u + "," + users[u] + ","
	lw = lw + ",".join(tw)
	outhandle.write(lw + "\n")

outhandle.close()
