# %%
import json, sys, re, time, dns
import pymongo, sys
from pymongo import MongoClient
from datetime import datetime, timedelta
import tweepy
from twitter import *

# %%
uri = "mongodb+srv://zvb5133:Bi19970130!@plsc508.1ejljrz.mongodb.net/?retryWrites=true&w=majority"
cluster = pymongo.MongoClient(uri)
db = cluster['PLSC508']
sp = db.Barbera2015
    # query only those tweets coming from users who passed our filter
data = sp.find({'followers_count':{'$gte':25},
        'statuses_count':{'$gte':100},
        'friends_count':{'$gte':100} },
        ['user_id_str','id_str', 'followers_count', 'lang', 'location'])

consumer_key = '3vQSi5O49WuSXwtrPpCF2gzRc'
consumer_secret = 'XwyX95s16KGtPgSHryamnjQJpiokzT4AtQB35j8JDRK7IQFQmN'
access_token = '1314960594043310080-p8kauSNNsmrqC21eXU2aBnM5OFvw6A'
access_token_secret = 'cRdNjjnfYADGlVrd6ktLAO7Lv9DswByYFhCDgcEVr2pBX'




twitter = Twitter(auth = OAuth(access_token,
                  access_token_secret,
                  consumer_key,
                  consumer_secret))

# for entries in data:
#     temp = twitter.statuses.retweets._id(_id = entries['id_str'])
#     print(temp)
#     retweet_statuses.append(temp)

# %%
retweets_1 = twitter.statuses.retweets._id(_id = data[0]["id_str"])

retweeter = retweets_1[0]['retweeted_status']['user']['id_str']
tweeter_id = retweets_1[0]['user']['id_str']
print('retweeter: ', retweeter)
print('retweeted : ', tweeter_id)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 retweets_1 = twitter.statuses.retweets._id(_id = data[0]["id_str"])
# ----> 3 retweeter = retweets_1[0]['retweeted_status']['user']['id_str']
#       4 tweeter_id = retweets_1[0]['user']['id_str']
#       5 print('retweeter: ', retweeter)
#
# IndexError: list index out of range

# %%
retweets_1[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 retweets_1[0]
#
# IndexError: list index out of range

# %%
retweets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 retweets
#
# NameError: name 'retweets' is not defined

# %%
#==============================================================================
# 04-extract-retweets.py
# Purpose: extracts retweets (retweter and retweeted) from each of the tweet
# collections. [Note that we apply activity filters when extracting the
# retweets to make the process more efficient.]
# Author: Pablo Barbera
#==============================================================================

## Export retweets as edges, and store them in a different file
## for each collection and day, with the following format:
## "temp/retweets/retweets_list_COLLECTION_DATE.csv"
## Also note that ONLY automatic retweets are included.

# connecting to MongoDB
uri = "mongodb+srv://zvb5133:Bi19970130!@plsc508.1ejljrz.mongodb.net/?retryWrites=true&w=majority"
connection = pymongo.MongoClient(uri)

# collections = ["BostonBombing", "GunControl", "MinimumWage", 
# 	"USElection", "superbowl", "MarriageEquality", "Budget", "Syria", 
# 	"GovernmentShutdown", "oscars", "SOTU",	"olympics"]

collections = ["PLSC508"]


for col in collections:
    db = connection[col]
    sp = db.Barbera2015
    # query only those tweets coming from users who passed our filter
    data = sp.find({'followers_count':{'$gte':25},
        'statuses_count':{'$gte':100},
        'friends_count':{'$gte':100} },
        ['user_id_str','id_str', 'followers_count', 'lang', 'location'])
    

    retweets = []
    old_date = str('a')
    i = 0

    for t in data:
        if i % 1000 == 0:
            print (str(i))
            try:
#                 new_date = t['timestamp'].date()
#                 print(new_date)
                tweeter_id = t['user_id_str']
                tweet_id = t['id_str']
                print(tweeter_id)
                retweets = twitter.statuses.retweets._id(_id = tweet_id)
                print("retweet list is", retweets)
                if retweets == []:
                    continue
            except:
                print("exception")
                continue
            # when tweet date is new, open new file where tweets will be stored
            # (note that this assumes tweets are in order, which should almost always be the case!)
#             if new_date is not old_date:
#                 print(new_date)
            outhandle = open('/Users/alex/Documents/GitHub/PLSC508_rep/dowloaded/retweets/retweets_list_PLSC508.csv', 'a')
            for retweet in retweets:
                retweeted = retweet['retweeted_status']['user']['id_str']
                retweeter_id = retweet['user']['id_str']
                #retweeter = retweet['retweeted_status']['user']['id_str']
#                 outhandle.write("{0},{1}\n".format(retweet[0], retweet[1]))
                outhandle.write("{0},{1}\n".format(retweeted, retweeter_id)) 
            outhandle.close()  
                          
#         try:
#             retweeter = t['id_str']
#             retweeted = t['retweeted_status']['user']['id_str']
#         except:
#             continue
#         retweets.append([retweeter, retweeted])
#         i += 1
# Out:
# 0
# 353063439
# retweet list is []
# 0
# 16910252
# retweet list is []
# 0
# 96894306
# ...

# %%
retweeter
